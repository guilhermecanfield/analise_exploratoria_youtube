# %%
import pandas as pd
import json
from deepdiff import DeepDiff
import itertools

# %%
# Definindo o dicionário com os paths dos arquivos JSON
json_categorias = {
    'br': 'data/BR_category_id.json',
    'gb': 'data/GB_category_id.json',
    'ca': 'data/CA_category_id.json',
    'us': 'data/US_category_id.json'
}

# Criação de uma função para carregar e transformar os arquivos JSON
def carregar_transformar_json(path):
    # Carrega o JSON em um dataframe
    df = pd.read_json(path)
    
    # Expande a coluna 'items' em linhas separadas, pois esta está dentro de um dicionário
    items = pd.json_normalize(df['items'])
    
    return items

# Iterando sobre o dicionário para carregar os DataFrames transformados
df = {}
for key, path in json_categorias.items():
    df[key] = carregar_transformar_json(path)

# Criação de uma lista contendo os dataframes
lista_dfs = [df['br'],df['ca'],df['gb'],df['us']]

# %%
# Testando o número de linhas esperado se concatenar todos os dataframes
tamanho_esperado = 0
for df in lista_dfs:
    tamanho_esperado+=df.shape[0]

print(f"Todos os arquivos JSON possuem juntos {tamanho_esperado} registros.")
# Out:
# Todos os arquivos JSON possuem juntos 125 registros.

# %%
# Como o dataframe resultante da concatenação terá apenas 125 linhas
#  a concatenação será feita para facilitar a análise
df_json = pd.concat(lista_dfs).reset_index(drop=True)

# Análise do tamanho do dataframe resultante e tipagem das colunas
df_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   kind                125 non-null    object
#  1   etag                125 non-null    object
#  2   id                  125 non-null    object
#  3   snippet.title       125 non-null    object
#  4   snippet.assignable  125 non-null    bool
#  5   snippet.channelId   125 non-null    object
# dtypes: bool(1), object(5)
# memory usage: 5.1+ KB

# %%
# Remoção dos termos "snippet." do nome das colunas oriundas deste dicionário
df_json.rename(columns=lambda col: col.replace('snippet.', ''), inplace=True)

# Análise da contagem de registros por coluna
for col in df_json:
    print(df_json[col].value_counts(), '\n')
    print(f'{"-" * 100}', '\n')
# Out:
# kind
# youtube#videoCategory    125
# Name: count, dtype: int64
#
# ----------------------------------------------------------------------------------------------------
#
# etag
# IfWa37JGcqZs-jZeAyFGkbeh6bc    4
# 5XGylIs7zkjHh5940dsT5862m1Y    4
# 3IaZjRK8JeIkLMfRDX57P4FFb9A    4
# 2sKmjip5q7FHJgqkHvnpMDgmddE    4
# qJ2eDOZWUDj8fbFYAIG_yzPCYRc    4
# HwuNLGhBJ4PZCEurr-SoqvHuKx8    4
# 3F8eda4xnGzGFmlpsFaf5_YpOgU    4
# Z3yra5IR8n2bkjvv3ZheAOQ-tUk    4
# H6d6HrYDy3EAVAxQR8Z-ShEva1k    4
# 7fvdoCRRWE89SpB5UaOY8gGdbk0    4
# FD7naICnxxl8HOnZZJAzrWplzuU    4
# ZFbZGeeLYWolvmCLQM7m8Yio104    4
# M6Y5Av0CP45r5GgpzamLfHj41y4    4
# harT7v7A6516SPdkqp81Xy5yfBw    4
# LNgRKNynxC50MeYV9e6XLPX9JC4    4
# totPMF_82XTvVFy0ExFgoKhTklM    4
# tMfbFvkfuPP8YnUEqpr0gcR6aWU    4
# KEdEtUd4WGk_aACrYI03UhGE33w    4
# hHUhloYhyMMqVkQ4LH9sr3aRQoU    4
# gYzt8dB8mlod-84ipMtjynYe9xU    4
# IbGXblQi8v_nOsXjirhul1NVcH8    4
# Qi1csjh-POReitZEbR7CUw7dmao    4
# v2n6q4JttoL4uUbazrcxNQRGPZk    4
# QMEBz6mxVdklVaq8JwesPEw_4nI    4
# D1W6tq5mMMCV0wtNxf9A6g9wWjU    4
# I3IL9xGIM3MsULlqR4tvCsEKv98    4
# K_-7stg0kIU7eUBOPUa6j5fqIMQ    4
# 0Z6uGkj97NgjD-X3pkA-nL18Hqk    4
# 7mqChSJogdF3hSIL-88BfDE-W8M    4
# ra8H7xyAfmE2FewsDabE3TUSq10    4
# HCjFMARbBeWjpm6PDfReCOMOZGA    4
# AioSVwhKNpZ2bhtw9SJmrkfY5-I    1
# Name: count, dtype: int64
#
# ----------------------------------------------------------------------------------------------------
#
# id
# 1     4
# 2     4
# 44    4
# 43    4
# 42    4
# 41    4
# 40    4
# 39    4
# 38    4
# 37    4
# 36    4
# 35    4
# 34    4
# 33    4
# 32    4
# 31    4
# 30    4
# 28    4
# 27    4
# 26    4
# 25    4
# 24    4
# 23    4
# 22    4
# 21    4
# 20    4
# 19    4
# 18    4
# 17    4
# 15    4
# 10    4
# 29    1
# Name: count, dtype: int64
#
# ----------------------------------------------------------------------------------------------------
#
# title
# Comedy                   8
# Film & Animation         4
# Movies                   4
# Trailers                 4
# Shows                    4
# Shorts                   4
# Thriller                 4
# Sci-Fi/Fantasy           4
# Horror                   4
# Foreign                  4
# Family                   4
# Drama                    4
# Documentary              4
# Classics                 4
# Action/Adventure         4
# Anime/Animation          4
# Science & Technology     4
# Autos & Vehicles         4
# Education                4
# Howto & Style            4
# News & Politics          4
# Entertainment            4
# People & Blogs           4
# Videoblogging            4
# Gaming                   4
# Travel & Events          4
# Short Movies             4
# Sports                   4
# Pets & Animals           4
# Music                    4
# Nonprofits & Activism    1
# Name: count, dtype: int64
#
# ----------------------------------------------------------------------------------------------------
#
# assignable
# False    68
# True     57
# Name: count, dtype: int64
#
# ----------------------------------------------------------------------------------------------------
#
# channelId
# UCBR8-60-B28hp2BmDPdntcQ    125
# Name: count, dtype: int64
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
#  - Fazendo a análise dos registros por coluna a coincidência de todas as colunas possuírem grupos de 4 registros iguais em cada uma chamou a atenção, será feita uma análise comparativa dos dataframes e caso estejam iguais, será feita análise dos arquivos JSON que deram origem aos dataframes.

# %%
# Verificando um id aleatoriamente pois dá a impressão que os 4 JSON são iguais
df_json[df_json.id == '1']
# Out:
#                      kind                         etag id     snippet.title  \
# 0   youtube#videoCategory  IfWa37JGcqZs-jZeAyFGkbeh6bc  1  Film & Animation
# 31  youtube#videoCategory  IfWa37JGcqZs-jZeAyFGkbeh6bc  1  Film & Animation
# 62  youtube#videoCategory  IfWa37JGcqZs-jZeAyFGkbeh6bc  1  Film & Animation
# 93  youtube#videoCategory  IfWa37JGcqZs-jZeAyFGkbeh6bc  1  Film & Animation
#
#     snippet.assignable         snippet.channelId
# 0                 True  UCBR8-60-B28hp2BmDPdntcQ
# 31                True  UCBR8-60-B28hp2BmDPdntcQ
# 62                True  UCBR8-60-B28hp2BmDPdntcQ
# 93                True  UCBR8-60-B28hp2BmDPdntcQ

# %%
# Gera todas as combinações únicas de pares de dataframes para observar se há diferença entre si
for i, j in itertools.combinations(range(len(lista_dfs)), 2):
    df1 = lista_dfs[i]
    df2 = lista_dfs[j]
    if df1.equals(df2):
        print(f"Os DataFrames df{i} e df{j} são iguais.")
    else:
        print(f"Os DataFrames df{i} e df{j} são diferentes.")
# Out:
# Os DataFrames df0 e df1 são iguais.
# Os DataFrames df0 e df2 são iguais.
# Os DataFrames df0 e df3 são diferentes.
# Os DataFrames df1 e df2 são iguais.
# Os DataFrames df1 e df3 são diferentes.
# Os DataFrames df2 e df3 são diferentes.

# %%
# Função para carregar arquivos JSON usando a lib json
def carregar_json(path):
    with open(path, 'r') as file:
        return json.load(file)

# Dicionário com os paths dos arquivos JSON
json_categorias = {
    'us': 'data/US_category_id.json',
    'br': 'data/BR_category_id.json',
    'gb': 'data/GB_category_id.json',
    'ca': 'data/CA_category_id.json'
}

# Carrega conteúdos dos arquivos
json_data = {key: carregar_json(path) for key, path in json_categorias.items()}

# Função para comparar dois JSONs e imprimir diferenças
def comparar_jsons(json1, json2, key1, key2):
    diff = DeepDiff(json1, json2, ignore_order=True)
    if diff:
        print(f"Diferenças entre {key1} e {key2}:")
        print(diff)
    else:
        print(f"Não há diferenças entre {key1} e {key2}.")

# Comparar cada par de arquivos JSON
chaves = list(json_categorias.keys())
for i in range(len(chaves)):
    for j in range(i + 1, len(chaves)):
        key1 = chaves[i]
        key2 = chaves[j]
        comparar_jsons(json_data[key1], json_data[key2], key1, key2)
# Out:
# Diferenças entre us e br:
# {'values_changed': {"root['etag']": {'new_value': 'kBCr3I9kLHHU79W4Ip5196LDptI', 'old_value': 'HIrK3n45Uw2IYz9_U2-gK1OsXvo'}}, 'iterable_item_removed': {"root['items'][16]": {'kind': 'youtube#videoCategory', 'etag': 'AioSVwhKNpZ2bhtw9SJmrkfY5-I', 'id': '29', 'snippet': {'title': 'Nonprofits & Activism', 'assignable': True, 'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}}}}
# Diferenças entre us e gb:
# {'values_changed': {"root['etag']": {'new_value': 'kBCr3I9kLHHU79W4Ip5196LDptI', 'old_value': 'HIrK3n45Uw2IYz9_U2-gK1OsXvo'}}, 'iterable_item_removed': {"root['items'][16]": {'kind': 'youtube#videoCategory', 'etag': 'AioSVwhKNpZ2bhtw9SJmrkfY5-I', 'id': '29', 'snippet': {'title': 'Nonprofits & Activism', 'assignable': True, 'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}}}}
# Diferenças entre us e ca:
# {'values_changed': {"root['etag']": {'new_value': 'kBCr3I9kLHHU79W4Ip5196LDptI', 'old_value': 'HIrK3n45Uw2IYz9_U2-gK1OsXvo'}}, 'iterable_item_removed': {"root['items'][16]": {'kind': 'youtube#videoCategory', 'etag': 'AioSVwhKNpZ2bhtw9SJmrkfY5-I', 'id': '29', 'snippet': {'title': 'Nonprofits & Activism', 'assignable': True, 'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}}}}
# Não há diferenças entre br e gb.
# Não há diferenças entre br e ca.
# Não há diferenças entre gb e ca.

# %% [markdown]
# **Os arquivos ``BR_category_id.json`` ``GB_category_id.json`` ``CA_category_id.json`` são exatamente iguais e a única diferença entre eles e o arquivo ``US_category_id.json`` é a chave principal (root) "etag"**
#
# É provável que as análises relacionadas a categorização dos vídeos seja comprometida em virtude da falta de dados relacionados a esta!

# %%
# Dropando as linhas duplicadas do dataframe para reduzir 
# a dimensão do mesmo e evitar posteriores problemas de join
df_json.drop_duplicates(inplace=True, ignore_index=True)

# %%
# Define o nome da variável que irá armezar o dataframe na chave, 
# e o path do arquivo no valor
dfs = {'br':'data/BR_youtube_trending_data.csv',
       'us':'data/US_youtube_trending_data.csv',
       'ca':'data/CA_youtube_trending_data.csv',
       'gb':'data/GB_youtube_trending_data.csv'}

dfs_dataframes = {}
lista_dfs_csv = []

# Iterando sobre os items da lista para criar os dataframes
for country, path in dfs.items():
    # Lê o arquivo CSV
    df = pd.read_csv(path)
    # Adiciona uma coluna 'country' com o nome do país
    df['country'] = country
    # Transforma a sigla no nome do país
    df['country'] = df['country'].map({'br':'Brasil',
                                       'us':'Estados Unidos',
                                       'ca':'Canada',
                                       'gb':'Reino Unido'})
    # Atribui o dataframe a uma variável global com o nome do país
    dfs_dataframes[country] = df
    lista_dfs_csv.append(dfs_dataframes[country])

# %%
tamanho_esperado_csv = 0
memoria_usada_total = 0
for i, file in enumerate(lista_dfs_csv):
    memoria_usada = round(file.memory_usage().sum() / (1024**2), 1)
    print(f"O {i + 1}o arquivo possui shape {file.shape[0]:,} linhas e {file.shape[1]} colunas. -> {memoria_usada} MB")
    tamanho_esperado_csv += file.shape[0]
    memoria_usada_total += memoria_usada

print(f"\nO tamanho total esperado do dataframe é {tamanho_esperado_csv:,} linhas -> {memoria_usada_total:.1f} MB.")
# Out:
# O 1o arquivo possui shape 63,193 linhas e 17 colunas. -> 7.4 MB
# O 2o arquivo possui shape 57,191 linhas e 17 colunas. -> 6.7 MB
# O 3o arquivo possui shape 57,144 linhas e 17 colunas. -> 6.6 MB
# O 4o arquivo possui shape 57,195 linhas e 17 colunas. -> 6.7 MB
#
# O tamanho total esperado do dataframe é 234,723 linhas -> 27.4 MB.

# %% [markdown]
#  - Ainda que o dataframe fique grande em termos de linhas, o espaço em memória ocupado será pequeno e a concatenação é válida pois facilitará a análise.

# %%
# Concatena os 4 dataframes e reseta o index para facilitar a análise
df_csv = pd.concat(lista_dfs_csv).reset_index(drop=True)

# %%
# Verificando o resultado da concatenação
df_csv
# Out:
#            video_id                                              title  \
# 0       s9FH4rDMvds     LEVEI UM FORA? FINGI ESTAR APAIXONADO POR ELA!
# 1       jbGRowa5tIk                          ITZY “Not Shy” M/V TEASER
# 2       3EfkCrXKZNs                      Oh Juliana PARÓDIA - MC Niack
# 3       gBjox7vn3-g   Contos de Runeterra: Targon | A Estrada Tortuosa
# 4       npoUGx7UW7o  Entrevista com Thammy Miranda | The Noite (10/...
# ...             ...                                                ...
# 234718  fiWxNzG5rOw  I Cheated with ONE WAY GLASS in a Building Com...
# 234719  z1mcEjHobr8  STEADY! Headie One - Daily Duppy | GRM Daily -...
# 234720  -Ot0vHUyEpw  The Weeknd - The Weeknd – Save Your Tears (Liv...
# 234721  t-Y-1Ki6LEk  ETERNALS Trailer: Every EASTER EGG  + Captain ...
#
#                                         thumbnail_link  comments_disabled  \
# 0       https://i.ytimg.com/vi/s9FH4rDMvds/default.jpg              False
# 1       https://i.ytimg.com/vi/jbGRowa5tIk/default.jpg              False
# 2       https://i.ytimg.com/vi/3EfkCrXKZNs/default.jpg               True
# 3       https://i.ytimg.com/vi/gBjox7vn3-g/default.jpg              False
# 4       https://i.ytimg.com/vi/npoUGx7UW7o/default.jpg              False
# ...                                                ...                ...
# 234718  https://i.ytimg.com/vi/fiWxNzG5rOw/default.jpg              False
# 234719  https://i.ytimg.com/vi/z1mcEjHobr8/default.jpg              False
# 234720  https://i.ytimg.com/vi/-Ot0vHUyEpw/default.jpg              False
# 234721  https://i.ytimg.com/vi/t-Y-1Ki6LEk/default.jpg              False
# 234722  https://i.ytimg.com/vi/MFPpeXTEcDM/default.jpg              False
#
#         ratings_disabled                                        description  \
# 0                  False  Salve rapaziada, neste vídeo me declarei pra e...
# 1                  False  ITZY Not Shy M/V[ITZY Official] https://www.yo...
# 2                  False  Se inscrevam meus amores! 📬 Quer nos mandar al...
# 3                  False  Você se unirá aos Lunari e aos Solari em Targo...
# 4                  False  Danilo Gentili recebe Thammy Miranda. Após pas...
# ...                  ...                                                ...
# 234718             False  Skeppy & BadBoyHalo Troll Antfrost, RedVelvet,...
# 234719             False  A Steady Duppy.LINK TO ORIGINAL VIDEO: https:/...
# 234720             False  “Save Your Tears” (Live at The 2021 Billboard ...
# 234721             False  Marvel just unleashed their first trailer for ...
# 234722             False  Has the Porsche Taycan's brother-from-another-...
#
#             country
# 0            Brasil
# 1            Brasil
# 2            Brasil
# 3            Brasil
# 4            Brasil
# ...             ...
# 234718  Reino Unido
# 234719  Reino Unido
# 234720  Reino Unido
# 234721  Reino Unido
# 234722  Reino Unido
#
# [234723 rows x 17 columns]

# %%
# Verifica o tamanho do dataframe concatenado e a tipagem das colunas
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234723 entries, 0 to 234722
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   video_id           234723 non-null  object
#  1   title              234723 non-null  object
#  2   publishedAt        234723 non-null  object
#  3   channelId          234723 non-null  object
#  4   channelTitle       234723 non-null  object
#  5   categoryId         234723 non-null  int64
#  6   trending_date      234723 non-null  object
#  7   tags               234723 non-null  object
#  8   view_count         234723 non-null  int64
#  9   likes              234723 non-null  int64
#  10  dislikes           234723 non-null  int64
#  11  comment_count      234723 non-null  int64
#  12  thumbnail_link     234723 non-null  object
#  13  comments_disabled  234723 non-null  bool
#  14  ratings_disabled   234723 non-null  bool
#  15  description        231678 non-null  object
#  16  country            234723 non-null  object
# dtypes: bool(2), int64(5), object(10)
# memory usage: 27.3+ MB

# %%
# Recordando a tipagem do dataframe de categorias
df_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   kind                32 non-null     object
#  1   etag                32 non-null     object
#  2   id                  32 non-null     object
#  3   snippet.title       32 non-null     object
#  4   snippet.assignable  32 non-null     bool
#  5   snippet.channelId   32 non-null     object
# dtypes: bool(1), object(5)
# memory usage: 1.4+ KB

# %% [markdown]
# ## Pré Processamento dos Dados

# %%
# Altera a tipagem do id do dataframe dos vídeos para possibilitar o merge com a tabela de categorias
df_csv['categoryId'] = df_csv['categoryId'].astype('str')

# %%
# Compara se alguma categoria do dataframes de video não está no dataframe de categorias
set(df_csv.categoryId.unique()).difference(set(df_json.id.unique()))
# Out:
# set()

# %%
# Compara se alguma categoria dataframe de categorias não está no dataframes de video, ou seja, não será utilizada no BI 
categorias_nao_aparecem = set(set(df_json.id.unique())).difference(df_csv.categoryId.unique())
print(f"{len(categorias_nao_aparecem)} categorias não estão presentes no dataframe de vídeos\
 e por isso serão dropadas. \nAlém de diminuir a dimensão da tabela, irá melhorar a experiência com o BI.")
# Filtragem apenas das categorias existentes no dataframe de videos
df_json = df_json[~df_json.id.isin(categorias_nao_aparecem)].copy()
# Out:
# 17 categorias não estão presentes no dataframe de vídeos e por isso serão dropadas.
# Além de diminuir a dimensão da tabela, irá melhorar a experiência com o BI.

# %% [markdown]
#  - Todas as categorias do dataframe de vídeos foram encontradas no dataframe de categorias. Assim sendo, não haverá nenhum prejuízo na análise em decorrência dos arquivos JSON serem iguais.

# %%
# Transformando as colunas de data em datetime e removendo o horário
df_csv['publishedAt'] = pd.to_datetime(df_csv['publishedAt']).dt.date # Remove Hora, minuto, segundo
df_csv['publishedAt'] = pd.to_datetime(df_csv['publishedAt'], format='%y-%m-%d') # Transforma para data
df_csv['trending_date'] = pd.to_datetime(df_csv['trending_date']).dt.date # Remove Hora, minuto, segundo
df_csv['trending_date'] = pd.to_datetime(df_csv['trending_date'], format='%y-%m-%d') # Transforma para data

# %%
# Transformação das colunas booleanas e a coluna país em category para reduzir o uso de memoria do dataframe
df_csv['comments_disabled'] = df_csv['comments_disabled'].astype('category')
df_csv['ratings_disabled'] = df_csv['ratings_disabled'].astype('category')
df_csv['country'] = df_csv['country'].astype('category')

# %%
# Criação de coluna que booleana que mapeia vídeos comuns aos 4 países

# Localiza os vídeos que estão presentes na tabela de todos os países
videos_comuns_a_todos = df_csv.groupby('title').agg({'country':'nunique'}).query('country>3')
lista_videos_comuns_a_todos = list(videos_comuns_a_todos.index)
df_csv['todos'] = 'N'
df_csv.loc[df_csv.title.isin(lista_videos_comuns_a_todos), 'todos'] = 'S'
df_csv['todos'] = df_csv['todos'].astype('category')

# %%
# Avaliação do dataframe resultante após os pré-processamentos
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234723 entries, 0 to 234722
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   video_id           234723 non-null  object
#  1   title              234723 non-null  object
#  2   publishedAt        234723 non-null  datetime64[ns]
#  3   channelId          234723 non-null  object
#  4   channelTitle       234723 non-null  object
#  5   categoryId         234723 non-null  object
#  6   trending_date      234723 non-null  datetime64[ns]
#  7   tags               234723 non-null  object
#  8   view_count         234723 non-null  int64
#  9   likes              234723 non-null  int64
#  10  dislikes           234723 non-null  int64
#  11  comment_count      234723 non-null  int64
#  12  thumbnail_link     234723 non-null  object
#  13  comments_disabled  234723 non-null  category
#  14  ratings_disabled   234723 non-null  category
#  15  description        231678 non-null  object
#  16  country            234723 non-null  category
#  17  todos              234723 non-null  category
# dtypes: category(4), datetime64[ns](2), int64(4), object(8)
# memory usage: 26.0+ MB

# %% [markdown]
# ### Análise de colunas para detecção de problemas que podem ocorrer no Power BI

# %%
# Analisando registros por colunas
for col in df_csv:
    print(df_csv[col].value_counts(), '\n')
    print(f'{"-" * 100}', '\n')
# Out:
# video_id
# wY6UyatwVTA    48
# pvPsJFRGleA    45
# IKKbboquS9s    41
# tQ0yjYUFKAE    40
# QcS9ZndErHc    39
#                ..
# t7TRtf-6hIo     1
# koqnU50NMxk     1
# Pyypif-xtK8     1
# Kn5ntXJJleU     1
# ayE5rF-BzeE     1
# Name: count, Length: 27061, dtype: int64
#
# ----------------------------------------------------------------------------------------------------
#
# title
# Starlink Mission                                                                                   216
# We Broke Up                                                                                         58
# India claim stunning series win, end Australia's Gabba streak | Vodafone Test Series 2020-21        48
# we broke up                                                                                         48
# Justin Bieber - Holy ft. Chance The Rapper                                                          45
#                                                                                                   ...
# what if to do this... #shorts                                                                        1
# Pro Motocross Round No. 1 Pala, California | EXTENDED HIGHLIGHTS | 5/29/21 | Motorsports on NBC      1
# Toto Wolff reacts to disastrous Monaco showing for Mercedes!                                         1
# INGLATERRA X IRLANDA                                                                                 1
# Live Dennis Dj Ruffles Porto 2020                                                                    1
# Name: count, Length: 27569, dtype: int64
#
# ----------------------------------------------------------------------------------------------------
#
# publishedAt
# 2020-12-22    1215
# 2020-10-30    1214
# 2021-03-15    1142
# 2020-09-08    1141
# 2021-02-28    1135
#               ...
# 2021-06-15      40
# 2020-08-03      13
# 2020-08-05      12
# 2020-08-01       6
# 2020-07-27       3
# Name: count, Length: 318, dtype: int64
#
# ----------------------------------------------------------------------------------------------------
#
# channelId
# UCMmVPVb0BwSIOWVeDwlPocQ    889
# UCWJ2lWNubArHWmf3FIHbfcQ    842
# UCNAf1k0yIjyGu3k9BwAg3lg    814
# UCV306eHqgo0LvBf3Mh36AHg    768
# UCDVYQ4Zhbm3S2dlz7P1GBDg    740
#                            ...
# UCnnKQEdBsb9-r1YkMKUzBPA      1
# UCIqOFV49mExgNpEnQL9jJQQ      1
# UCiTYUFWXAdIufyN2d7rXZyw      1
# UC9yadlAEiyOUNa3y4dnuYFg      1
# UCNU0Vv6U1xZS82cIQrgDeqw      1
# Name: count, Length: 7187, dtype: int64
#
# ----------------------------------------------------------------------------------------------------
#
# channelTitle
# The United Stand            889
# NBA                         842
# Sky Sports Football         814
# Felipe Neto                 768
# NFL                         740
#                            ...
# Nanda Benitez                 1
# Jorge & Mateus - Topic        1
# Márcia Suzuki Pâtisserie      1
# THE YB                        1
# Mkfray                        1
# Name: count, Length: 7284, dtype: int64
#
# ----------------------------------------------------------------------------------------------------
#
# categoryId
# 24    53879
# 10    44824
# 17    33536
# 20    26076
# 22    22884
# 23    13093
# 28     8378
# 25     7794
# 26     6867
# 1      6155
# 27     5063
# 2      3906
# 15     1061
# 19     1034
# 29      173
# Name: count, dtype: int64
#
# ----------------------------------------------------------------------------------------------------
#
# trending_date
# 2021-02-24    1600
# 2021-03-02    1600
# 2021-05-31    1600
# 2021-06-01    1600
# 2021-05-09     800
#               ...
# 2021-06-12     400
# 2021-06-13     400
# 2021-06-14     400
# 2021-06-15     400
# 2021-06-16     400
# Name: count, Length: 297, dtype: int64
#
# ----------------------------------------------------------------------------------------------------
#
# tags
# [None]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               31896
# BIGHIT|빅히트|방탄소년단|BTS|BANGTAN|방탄                                                                                                                                                                                                                                                                                                                                                                                                                                                                        426
# VLOG|Estados|Unidos|EUA|Brasil|Brazil|Breakmen|Casa|House                                                                                                                                                                                                                                                                                                                                                                                                                                              347
# liga nfa|nfa|liga|free fire|garena|lbff|copa ff|liga brasileira|pro player|campeonato|torneio|ss|bdl|b4|los grandes|lgd|loud|loudgg|laude|pain|faz o p|god|god esports|deuses|kof|anarchysons|intz|fsk|forsaken|samuca|ale|el|gato|piu|piuzinho|thurzin|maellen|booyah|voltan|codiguin|cerol|bak|coreano|jordan|racha|price|elton|eltin|huntergod|wins|hudson|nobru|tv|ygorx|dantes|since|sharin|will|bradook|kronos|ggeasy|babi|coringa|victor|levelup|buxexa|crusherfooxi|esports|blak|blakn444      341
# sidemen|moresidemen|miniminter|ksi|zerkaa|behzinga|tbjzl|vikkstar|wroetoshaw                                                                                                                                                                                                                                                                                                                                                                                                                           309
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
HERE : cases4bailey@gmail.com Business Related Emails : baileysarian@slashmgmt.com________               PRODUCTS USED FACE YSL Touche Eclat Le Teint Radiant Liquid Foundation Shade BD25 - https://shop-links.co/1741468464495759458 Jouer Concealer Shade Chiffon - https://shop-links.co/1742056040101907487 Laura Mercier Loose Setting Powder Translucent - https://shop-links.co/1741468542044495461 Tom Ford Shade and Illuminate Cream Face Palette Shade Intensity 01 - https://shop-links.co/1741468564444911986 Scott Barnes Sculpting and Contour Palette - https://shop-links.co/1741469011406000659 Scott Barnes Blush Palette - https://shop-links.co/1741468954236729654 Hourglass Ambient Strobe Lighting Powder Color Brilliant - https://shop-links.co/1742056437094195166EYES Rare Beauty Liquid Eyeshadow Shade Nearly Neutral - https://shop-links.co/1741468609061629893 Natasha Denona Palette Gold Palette - https://shop-links.co/1742056093375449415 Make Up For Ever Gold Pigment ( I got my brush wet before applying) - https://shop-links.co/1742056299111585221 Urban Decay Lash Freak Mascara - https://shop-links.co/1742056341091914905 Ardell Double Demi Wispy Lashes - https://shop-links.co/1742056369385107732BROWS Anastasia Beverly Hills Brow Freeze Styling Wax - https://shop-links.co/1741468648028365776 Benefit Brow Pen Dark Brown - https://shop-links.co/1741468691054065670LIPS Melt Cosmetics Liquid Lipstick Color Breathless - https://shop-links.co/1742056577776171337♡ *These links are affiliate links. which means, if you click on the link and purchase product, a small percentage comes back to me. It helps me keep on keepin on with my videos and I appreciate you if you choose to support. If you don’t, that’s ok too.                                                                                                                                                                                                                                                                                                                                                                                                  1
# Name: count, Length: 27549, dtype: int64
#
# ----------------------------------------------------------------------------------------------------
#
# country
# Brasil            63193
# Reino Unido       57195
# Estados Unidos    57191
# Canada            57144
# Name: count, dtype: int64
#
# ----------------------------------------------------------------------------------------------------
#
# todos
# N    219504
# S     15219
# Name: count, dtype: int64
#
# ----------------------------------------------------------------------------------------------------

# %%
# Avaliando Ids com mais de um título
df_csv.groupby('channelId').agg({'channelTitle':'nunique'}).query('channelTitle>1').sort_values('channelTitle', ascending=False)
# Out:
#                           channelTitle
# channelId
# UCQG-g3mLDliBH180J6nmqKg             5
# UC-2XiVy5AbEn2TXf0f2APeQ             3
# UC9APf0VQtg1VriRFjk9RfFQ             3
# UCj34AOIMl_k1fF7hcBkD_dw             3
# UCVepIJedg6BMQeSgjPY4e6A             3
# ...                                ...
# UCz7sPJrTGM3x41_RnptajyQ             2
# UCzCutgYFZpBdElMw3krjG0A             2
# UCzwFZOhCfCZTgLruMz_RWCw             2
# UCzz4CoEgSgWNs9ZAvRMhW2A             2
# UCzznO4xSV8BKnUBPyswtCUw             2
#
# [106 rows x 1 columns]

# %%
df_csv.groupby('channelTitle').agg({'channelId':'nunique'}).query('channelId>1')
# Out:
#                             channelId
# channelTitle
# CONMEBOL Libertadores               2
# ESPN Brasil                         2
# GOT7                                2
# HanRidge                            2
# MTV                                 2
# SML                                 2
# THE BOYZ                            2
# TODAY                               2
# Various Artists - Topic             8
# YoungBoy Never Broke Again          2
# Zé Vaqueiro - Topic                 2

# %%
# Ids de canais com mais de um título
ids_mais_titulo = df_csv.groupby('channelId').agg({'channelTitle':'nunique'}).query('channelTitle>1').index

n_titulos = df_csv[df_csv['channelId'].isin(ids_mais_titulo)].channelTitle.nunique()

print(f"{len(ids_mais_titulo)} Ids de canais, possuem mais de um título associado,\
 isso significa que 'channelId' não é uma chave primária.\nEsses {len(ids_mais_titulo)} Ids possuem\
 {n_titulos} títulos associados.")
# Out:
# 106 Ids de canais, possuem mais de um título associado, isso significa que 'channelId' não é uma chave primária.
# Esses 106 Ids possuem 220 títulos associados.

# %%
# Títulos de canais com mais de um Id
titulos_mais_ids = df_csv.groupby('channelTitle').agg({'channelId':'nunique'}).query('channelId>1').index

n_ids = df_csv[df_csv['channelTitle'].isin(titulos_mais_ids)].channelId.nunique()

print(f"{len(titulos_mais_ids)} títulos de canais, possuem mais de um Id,\
 isso significa que 'channelTitle' também não é uma chave primária.\nEsses {len(titulos_mais_ids)} títulos possuem\
 {n_ids} Ids associados.")
# Out:
# 11 títulos de canais, possuem mais de um Id, isso significa que 'channelTitle' também não é uma chave primária.
# Esses 11 títulos possuem 28 Ids associados.

# %%
# Ids de videos com mais de um título
ids_mais_titulo = df_csv.groupby('video_id').agg({'title':'nunique'}).query('title>1').index

n_titulos = df_csv[df_csv['video_id'].isin(ids_mais_titulo)].title.nunique()

print(f"{len(ids_mais_titulo)} Ids de vídeos, possuem mais de um título associado,\
 isso significa que 'video_id' não é uma chave primária.\nEsses {len(ids_mais_titulo)} Ids possuem\
 {n_titulos} títulos associados.")
# Out:
# 546 Ids de vídeos, possuem mais de um título associado, isso significa que 'video_id' não é uma chave primária.
# Esses 546 Ids possuem 1146 títulos associados.

# %%
# Títulos de vídeos com mais de um Id
titulos_mais_ids = df_csv.groupby('title').agg({'video_id':'nunique'}).query('video_id>1').index

n_ids = df_csv[df_csv['title'].isin(titulos_mais_ids)].video_id.nunique()

print(f"{len(titulos_mais_ids)} títulos de vídeos, possuem mais de um Id,\
 isso significa que 'title' não é uma chave primária.\nEsses {len(titulos_mais_ids)} títulos possuem\
 {n_ids} Ids associados.")
# Out:
# 59 títulos de vídeos, possuem mais de um Id, isso significa que 'title' não é uma chave primária.
# Esses 59 títulos possuem 151 Ids associados.

# %%
# Verificação de duplicações
df_csv[df_csv.duplicated()]
# Out:
#            video_id                                              title  \
# 8299    OUZgxTQYST0               Live - Chiclete com Banana - Vintage
# 38398   92MOgwbgG7U  500 SEGREDOS DO MINECRAFT QUE VOCÊ NÃO SABIA (...
# 38424   YBemdKjn59E           Roda Viva | Teresa Cristina | 22/02/2021
# 38426   wmZEliQOsDc                         NOOB NO CÉU | PARAFERNALHA
# 38427   X5SxRpbhMxM           Live de atualizações coronavirus (22/02)
# ...             ...                                                ...
# 216117  qwcDqoTT6Xo  Handforth Parish Council Planning Meeting foll...
# 216118  QBFiiEVBWvE  NASA Mars 2020 Perseverance Rover Landing! 🔴 Live
# 216120  br_cKwfR8gI                  Pyra / Mythra in Smash!!! Nice!!!
# 216121  u613yk4RGGw  Driving My Wrecked Mclaren 675LT For The First...
# 216123  IVHbzcr1-D8                        Nintendo Direct - 2.17.2021
#
#        publishedAt                 channelId                  channelTitle  \
# 38398             False  📷 MEU INSTAGRAM: https://www.instagram.com/olu...
# 38424             False  No Roda Viva, a jornalista Vera Magalhães rece...
# 38426             False  Samuca é um noob que bateu as botas e foi para...
# 38427             False                              Inscreva-se no canal!
# ...                 ...                                                ...
# 216117            False                                                NaN
# 216118            False  Mars 2020 is a Mars rover mission by NASA's Ma...
# 216120            False                 neat#SmashBros #Reaction #Episode1
# 216121            False  Find the world's BEST DEALS on cars with AutoT...
# 216123            False  Tune in to a Nintendo Direct presentation feat...
#
#             country todos
# 8299         Brasil     N
# 38398        Brasil     N
# 38424        Brasil     N
# 38426        Brasil     N
# 38427        Brasil     N
# ...             ...   ...
# 216117  Reino Unido     N
# 216118  Reino Unido     N
# 216120  Reino Unido     N
# 216121  Reino Unido     N
# 216123  Reino Unido     N
#
# [405 rows x 18 columns]

# %%
# Escolha aleatória de um registro para análise
df_csv[df_csv.title == 'Roda Viva | Teresa Cristina | 22/02/2021'].sort_values(['likes','dislikes'])
# Out:
#           video_id                                     title publishedAt  \
# 38224  YBemdKjn59E  Roda Viva | Teresa Cristina | 22/02/2021  2021-02-23
# 38424  YBemdKjn59E  Roda Viva | Teresa Cristina | 22/02/2021  2021-02-23
# 38658  YBemdKjn59E  Roda Viva | Teresa Cristina | 22/02/2021  2021-02-23
# 38868  YBemdKjn59E  Roda Viva | Teresa Cristina | 22/02/2021  2021-02-23
# 39074  YBemdKjn59E  Roda Viva | Teresa Cristina | 22/02/2021  2021-02-23
# 39337  YBemdKjn59E  Roda Viva | Teresa Cristina | 22/02/2021  2021-02-23
# 39563  YBemdKjn59E  Roda Viva | Teresa Cristina | 22/02/2021  2021-02-23
# 39770  YBemdKjn59E  Roda Viva | Teresa Cristina | 22/02/2021  2021-02-23
#
#                       channelId channelTitle categoryId trending_date  \
# 38224  UCNVsZnDXOM4PodYIEgM2e4w    Roda Viva         25    2021-02-24
# 38424  UCNVsZnDXOM4PodYIEgM2e4w    Roda Viva         25    2021-02-24
# 38658  UCNVsZnDXOM4PodYIEgM2e4w    Roda Viva         25    2021-02-25
# 38868  UCNVsZnDXOM4PodYIEgM2e4w    Roda Viva         25    2021-02-26
# 39074  UCNVsZnDXOM4PodYIEgM2e4w    Roda Viva         25    2021-02-27
# 39337  UCNVsZnDXOM4PodYIEgM2e4w    Roda Viva         25    2021-03-01
# 39563  UCNVsZnDXOM4PodYIEgM2e4w    Roda Viva         25    2021-03-02
# 39770  UCNVsZnDXOM4PodYIEgM2e4w    Roda Viva         25    2021-03-02
#
#                                                     tags  view_count  likes  \
# 38224  roda viva|tv cultura|debate|jornalismo|entrevi...       35417   3349
# 38424  roda viva|tv cultura|debate|jornalismo|entrevi...       35417   3349
# 38658  roda viva|tv cultura|debate|jornalismo|entrevi...       46778   3997
# 38868  roda viva|tv cultura|debate|jornalismo|entrevi...       50216   4197
# 39074  roda viva|tv cultura|debate|jornalismo|entrevi...       52485   4324
# 39337  roda viva|tv cultura|debate|jornalismo|entrevi...       57008   4589
# 39563  roda viva|tv cultura|debate|jornalismo|entrevi...       58083   4636
# 39770  roda viva|tv cultura|debate|jornalismo|entrevi...       58175   4646
#
#        dislikes  comment_count  \
# 38224       439            366
# 38424       439            366
# 38658       617            624
# 38868       653            688
# 39074       666            719
# 39337       699            760
# 39563       708            774
# 39770       709            778
#
#                                        thumbnail_link comments_disabled  \
# 38224  https://i.ytimg.com/vi/YBemdKjn59E/default.jpg             False
# 38424  https://i.ytimg.com/vi/YBemdKjn59E/default.jpg             False
# 38658  https://i.ytimg.com/vi/YBemdKjn59E/default.jpg             False
# 38868  https://i.ytimg.com/vi/YBemdKjn59E/default.jpg             False
# 39074  https://i.ytimg.com/vi/YBemdKjn59E/default.jpg             False
# 39337  https://i.ytimg.com/vi/YBemdKjn59E/default.jpg             False
# 39563  https://i.ytimg.com/vi/YBemdKjn59E/default.jpg             False
# 39770  https://i.ytimg.com/vi/YBemdKjn59E/default.jpg             False
#
#       ratings_disabled                                        description  \
# 38224            False  No Roda Viva, a jornalista Vera Magalhães rece...
# 38424            False  No Roda Viva, a jornalista Vera Magalhães rece...
# 38658            False  No Roda Viva, a jornalista Vera Magalhães rece...
# 38868            False  No Roda Viva, a jornalista Vera Magalhães rece...
# 39074            False  No Roda Viva, a jornalista Vera Magalhães rece...
# 39337            False  No Roda Viva, a jornalista Vera Magalhães rece...
# 39563            False  No Roda Viva, a jornalista Vera Magalhães rece...
# 39770            False  No Roda Viva, a jornalista Vera Magalhães rece...
#
#       country todos
# 38224  Brasil     N
# 38424  Brasil     N
# 38658  Brasil     N
# 38868  Brasil     N
# 39074  Brasil     N
# 39337  Brasil     N
# 39563  Brasil     N
# 39770  Brasil     N

# %%
# Escolha aleatória de outro registro para análise
df_csv[df_csv.title == 'Live - Chiclete com Banana - Vintage'].sort_values(['likes','dislikes'])
# Out:
#          video_id                                 title publishedAt  \
# 7806  OUZgxTQYST0  Live - Chiclete com Banana - Vintage  2020-09-20
# 8534  OUZgxTQYST0  Live - Chiclete com Banana - Vintage  2020-09-20
# 8298  OUZgxTQYST0  Live - Chiclete com Banana - Vintage  2020-09-20
# 8299  OUZgxTQYST0  Live - Chiclete com Banana - Vintage  2020-09-20
# 8775  OUZgxTQYST0  Live - Chiclete com Banana - Vintage  2020-09-20
#
#                      channelId         channelTitle categoryId trending_date  \
# 7806  UCKY0ExOhG86FyDmtr_aM6dg  Chiclete com Banana         10    2020-09-20
# 8534  UCKY0ExOhG86FyDmtr_aM6dg  Chiclete com Banana         10    2020-09-23
# 8298  UCKY0ExOhG86FyDmtr_aM6dg  Chiclete com Banana         10    2020-09-22
# 8299  UCKY0ExOhG86FyDmtr_aM6dg  Chiclete com Banana         10    2020-09-22
# 8775  UCKY0ExOhG86FyDmtr_aM6dg  Chiclete com Banana         10    2020-09-24
#
#         tags  view_count  likes  dislikes  comment_count  \
# 7806  [None]      164559   3182        73             36
# 8534  [None]      185172   3439       111             70
# 8298  [None]      183939   3439       113             69
# 8299  [None]      183939   3439       113             69
# 8775  [None]      186115   3475       111             75
#
#                                       thumbnail_link comments_disabled  \
# 7806  https://i.ytimg.com/vi/OUZgxTQYST0/default.jpg             False
# 8534  https://i.ytimg.com/vi/OUZgxTQYST0/default.jpg             False
# 8298  https://i.ytimg.com/vi/OUZgxTQYST0/default.jpg             False
# 8299  https://i.ytimg.com/vi/OUZgxTQYST0/default.jpg             False
# 8775  https://i.ytimg.com/vi/OUZgxTQYST0/default.jpg             False
#
#      ratings_disabled                                        description  \
# 7806            False  Live - Chiclete com Banana - Vintage#ChicleteC...
# 8534            False  Live - Chiclete com Banana - Vintage#ChicleteC...
# 8298            False  Live - Chiclete com Banana - Vintage#ChicleteC...
# 8299            False  Live - Chiclete com Banana - Vintage#ChicleteC...
# 8775            False  Live - Chiclete com Banana - Vintage#ChicleteC...
#
#      country todos
# 7806  Brasil     N
# 8534  Brasil     N
# 8298  Brasil     N
# 8299  Brasil     N
# 8775  Brasil     N

# %% [markdown]
#  - _Nas amostras as duplicações ficaram evidentes, será feito o drop_duplicates para remover futuras distorções das análises._

# %%
df_csv.drop_duplicates(inplace=True)

# %% [markdown]
# ### Análise Descritiva do DataFrame de Vídeos

# %%
# Configurar as opções de exibição para notação numérica normal
pd.set_option('display.float_format', lambda x: '%.0f' % x)

df_csv.describe(percentiles=[0.25,0.50,0.75,0.90,0.95,0.99])
# Out:
#                          publishedAt                  trending_date  \
# count                         234318                         234318
# mean   2021-01-04 00:59:30.409443328  2021-01-08 01:06:50.672675328
# min              2020-07-27 00:00:00            2020-08-12 00:00:00
# 25%              2020-10-20 00:00:00            2020-10-24 00:00:00
# 50%              2021-01-04 00:00:00            2021-01-09 00:00:00
# 75%              2021-03-19 00:00:00            2021-03-24 00:00:00
# 90%              2021-05-03 00:00:00            2021-05-07 00:00:00
# 95%              2021-05-17 00:00:00            2021-05-21 00:00:00
# 99%              2021-06-05 00:00:00            2021-06-11 00:00:00
# max              2021-06-15 00:00:00            2021-06-16 00:00:00
# std                              NaN                            NaN
#
#        view_count    likes  dislikes  comment_count
# count      234318   234318    234318         234318
# mean      2274622   136694      2853          13538
# min             0        0         0              0
# 25%        342668    15502       260           1059
# 50%        812326    43137       678           2854
# 75%       1958411   116349      1928           7854
# 90%       4694064   284208      5171          20513
# 95%       8256343   493615     10372          38902
# 99%      25712309  1600780     35983         146787
# max     278080610 16213756    879357        6817450
# std       6210057   418920     14202         111339

# %% [markdown]
# ### Geração dos arquivos pré-processados no python
#  - _Os arquivos serão salvos no formato parquet para otimizar a utilização de espaço de armazenamento._

# %%
df_csv.to_parquet('youtube_videos.parquet', index=False)
df_json.to_parquet('categorias.parquet', index=False)

# %% [markdown]
# **As próximas etapas serão executadas no ``Power BI``**
#
# [![Acesse o Dashboard](https://img.shields.io/badge/PowerBI-F2C811?style=for-the-badge&logo=Power%20BI&logoColor=white)](https://app.powerbi.com/view?r=eyJrIjoiZmFiZTNmNmYtOWQwMy00Mzc0LThhMzgtYmEzNjI0MjMwNDM3IiwidCI6ImRlYTcxOWY4LWZmODEtNDRlZi1hMjljLTIyMmMxMGYyZmVhYSJ9)
